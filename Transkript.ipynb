# %% [markdown]
# Was ist objektorientierte Programmierung?
# Wenn Sie hier bestimmte Zeilen im Transkript auswählen, wird die entsprechende Zeitmarke im Video angesteuert.
# dann sollten Sie einige Fachbegriffe und Konzepte kennen. Wir schauen uns in diesem Video an, was es dort an Begrifflichkeiten gibt und was sie bedeuten. Zuerst einmal was ist das Ziel der objektorientierten Programmierung. Es gibt ein Schlagwort, das ist die Wiederverwendbarkeit. Man erreicht in der objektorientierten Programmierung eine sehr hohe Wiederverwendbarkeit von Code, in dem man sehr stark modularisiert. die Daten und auch die Methoden von Objekten zusammenfasst, was auch immer das jetzt bedeutet. Und wenn man eine sehr strenge Datenkapselung vornimmt, dann wird man den Zugriff auf sämtliche Daten von Objekten möglichst nur noch indirekt gestatten. Das heißt, man hat eine sehr hohe Kontrolle über die Daten von Objekten. All das erfolgt dann mit dem Ziel, die Wiederverwendbarkeit möglichst hoch zu machen. Im Mittelpunkt der objektorientierten Programmierung stehen dabei die Klassen. Man kann sich Klassen einmal vorstellen als Baupläne für Objekte. Sie repräsentieren aber auch den Typ eines Objektes, den sogenannten Objekttyp. Und Klassen fassen alle relevanten Eigenschaften und Verhaltensweisen der davon repräsentierten Objekttypen zusammen. Man kann sagen, sie klassifizieren sie, wobei man sich immer darüber klar werden muss, dass Relevanz bedeutet, dass man eine Abstraktion der Wirklichkeit vornimmt. Der Begriff der Abstraktion ist dabei in der deutschen Sprache falsch besetzt, finde ich. Man sagt sehr oft, etwas ist mir zu abstrakt, und meint damit, es ist zu kompliziert. Aber eigentlich ist die Abstraktion eine Vereinfachung. Man betrachtet nur das, was einen interessiert, und das ist eben meine Vereinfachung, nicht etwas Kompliziertes. Und wie Klassen eben eine Abstraktion der Wirklichkeit darstellen, sind auch die daraus erzeugten Objekte eine Abstraktion eines realen Gegenstands oder eines Konzepts. Denken Sie beispielsweise an einen Stift. Sie werden einen Stift nur in deren Sicht in der Regel betrachten, wie er in Grade nützlich ist. Beispielsweise dass man damit malen oder schreiben kann, dass eine Farbe einen Typ hat. Für eine bestimmte Situation wird es aber uninteressant sein, dass es beispielsweise auch einen Preis gibt, was der kostet. In einer anderen Situation kann aber dieser Preis interessant sein. Das heißt, diese Abstraktion ist eben die Reduktion auf das, was gerade interessant ist. Konkrete Objekte verfügen nun aber auch über einen spezifischen Zustand und ein spezifisches Verhalten, was das eine Objekt von dem anderen Objekt unterscheiden kann. Zumindestens der Zustand kann sich unterscheiden. Denken Sie an verschiedene Stifte. Einige können beispielsweise einen Deckel haben, der auf ist, und andere Stifte einen Deckel, der zu ist. Grundsätzlich sind diese Objekte damit gleich, aber durch den veränderten Zustand stehen beispielsweise auch gewisse Methoden zur Verfügung zu einem gewissen Zeitpunkt und zu einem anderen Zeitpunkt eben nicht. Das Beispiel mit dem Stift, mit dem Deckel drauf oder eben nicht. Das würde bedeuten, dass man mit diesem Stift schreiben kann oder eben nicht. Die Objekte nennt man auch die sogenannten Instanzen einer Klasse. Und für die Bestandteile von einem Objekt wird der Begriff Member oder Mitglied benutzt. Das ist eben der Bestandteil eines Objekts respektive auch einer Klasse. Und man unterscheidet die Member in sogenannte Eigenschaften beziehungsweise Attribute auf der einen Seite und die Methoden oder Operationen auf der anderen Seite. Die Attribute sind die Beschreibung der objekt- und klassenbezogenen Daten, beispielsweise bei einem Objekt Stift die Farbe, der Typ. Es sind die Dinge, worüber sich die einzelnen Objekte unterscheiden, wobei man die Gleichsetzung von Attributen und Eigenschaften mit Vorsicht genießen muss. Meist ist das so, dass Attribute auch als Eigenschaften eines Objekts bezeichnet werden, alles gibt es gewisse Sprachen oder Konzepte, wo man dies unterscheidet. In der Regel aber ist es ein Synonym, Attribut oder Eigenschaft. Und es sind die passiven Member eines Objekts oder einer Klasse. Und wenn es passive Member gibt, dann gibt es sicherlich auch aktive und die nennt man die Methoden beziehungsweise Operationen eines Objekts beziehungsweise einer Klasse. Es geht hierbei um die Funktionalität, die ein Objekt haben kann. Wenn man wieder eine Stift betrachtet, wäre eine aktive Methode beispielsweise das Zeichnen oder Schreiben. Man kann mit diesen Methoden oder Operationen auch die Daten eines Objekts manipulieren oder auch abfragen. Kommen wir noch einmal zum Begriff der Abstraktion. Die Abstraktion ist wie gesagt im Grunde ganz gut mit Vereinfachung zu übersetzen. Und eine Vereinfachung erfolgt in der Regel durch eine Verallgemeinerung. Man betrachtet nicht die speziellen Dinge, Man nutzt diese Interfaces oder Schnittstellen, um ein gemeinsames Verhalten von verschiedenen Klassen oder Objekten zu gewährleisten. Man strukturiert damit Klassenbeziehungen. Und auch die sogenannten abstrakten Klassen machen es möglich, dass man in einem Klassenbaum bestimmte Operationen bereits vorgibt, aber noch nicht sagt, wie sie ganz konkret ablaufen. Sie müssen ... sein, aber man muss sie später noch spezialisieren, das heißt, man muss sie später noch in spezialisierten Klassen konkret implementieren. Ein weiterer Begriff, der in der objektorientierten Programmierung wichtig ist, ist die sogenannte Nachricht oder Botschaft. Das ist der Kommunikationsweg zwischen Objekten. Objekte kommunizieren über diese Botschaften. Und es gibt keine anderen Kommunikationswege in der strengen objektorientierten Programmierung. Was könnte es allen anderen Kommunikationswegen geben. Nun in der traditionellen Programmierung gibt es beispielsweise globale Variablen. Über diese könnte die Kommunikation laufen. Aber das ist in der objektorientierten Programmierung strengstens verboten, zumindestens wenn man die objektorientierte Programmierung konsequent umsetzt. In einigen Sprachen kann man objektorientiert arbeiten und trotzdem globale Variablen benutzen, aber das ist eben von der Philosophie nicht streng objektorientiert. Diese Nachrichten können in eine Richtung nur ausgetauscht werden oder in beide Richtungen. Das heißt, ein Objekt kann als Sender fungieren, ein anderes als Empfänger oder sie können wechselseitig Sender und Empfänger sein. Technisch werden solche Botschaften sehr oft über die sogenannte Punktnotation umgesetzt. Man schreibt den Namen eines Objekts hin, macht einen Punkt, ruft dann eine Methode oder Eigenschaft auf. Und damit wird dem Objekt eine Botschaft geschickt. Nun sollte man noch ein paar weitere Begriffe kennen, die in der OOP auftauchen. Das sind Objektbeziehungen beziehungsweise Aggregationen. Die Schlagworte hier sind Assoziationen, Kompositionen und Aggregationen. Das sind Mechanismen, um bestimmte Objekt- und Klassenbeziehungen auszudrücken. Eine Assoziation bezeichnet die Beziehung zwischen zwei oder mehr Teilnehmern Sie stehen in Beziehung zueinander. Eine Aggregation ist eine Beschreibung, dass ein Objekt nur als Teil eines anderen Objekts betrachtet wird, aber das Objekt kann auch ohne das umgebende Objekt existieren. Beispielsweise Sie haben ein Objekt Motor als Teil eines Autos, aber das Objekt Motor kann auch alleine existieren. Warum erwenigt das so besonders? Nun es gibt noch die Komposition. Im Prinzip wie eine Aggregation zu sehen ist nur, das Objekt selbst kann ohne ein umgebendes Objekt nicht existieren. Denken Sie beispielsweise an ein Haus, das ist das umbgebende Objekt, und ein Stockwerk darin. Das Stockwerk alleine kann nicht existieren, es muss Teil eines Hauses sein. Und eine Assoziation muss hervorgehoben werden, dass die Vererbung, denn die beschreibt ein Mechanismus, zum sogenannten Generalisieren und Spezialisieren von Objekttypen. Ein Generalisieren würde beispielsweise bedeuten, dass Sie ein Schwein, ein Rind und ein Schaf haben und davon eine sogenannte Superklasse bilden, nennen wir sie mal Tier. Der umgekehrte Weg, Sie haben ein Tier, Sie haben noch ein Tier, noch ein Tier, und diese Tiere unterscheiden sich, zwei Schweine, ein Rind. Dann würde das Spezialisieren bedeuten, man baut eine Klasse Schwein, eine Klasse Rind, und das sind dann Spezialisierung der übergeordneten Klasse des Objekttypes Und man kann über Vererbung Klassen in Form einer Hierarchie verknüpfen. So, und jetzt haben wir die wichtigsten Begriffe fast durch. Es gibt noch einen zum Abschluss, das ist der Begriff der Polymorphie. Polymorphie bedeutet Vielgestaltigkeit. Man versteht sehr oft darunter eine flexible Auswahl von geeigneten Methoden mit gleichen Namen auf Grund einer unterschiedlichen Argumentenliste. Das heißt, es gibt unterschiedliche Parameter. Das ist eine sehr enge Fassung der Polymorphie. Allgemein sollte man sich mit dem Begriff der Polymorphie ein vielgestaltiges Verhalten von Syntax-Strukturen aufgrund einer vorliegenden Situation vorstellen. Beispielsweise könnten Sie das Plus-Zeichen als Mathemage-Addition betrachten, wenn Sie zwei Zahlen an diesem Pluszeichen rechts und links notieren. Aber wenn Sie nur eine Zahl dem Plus-Zeichen nachstellen, dann haben Sie einen Vorzeichenoperator. Und damit haben Sie für dieses Zeichen Plus ein vielgestaltiges Verhalten. ein vielgestaltiges Verhalten. Also auch so etwas ist bereits Teil dessen, Also auch so etwas ist bereits Teil dessen, was man als Polymorphie bezeichnet. was man als Polymorphie bezeichnet. Sie haben also gesehen, Sie haben also gesehen, es gibt eine ganze Reihe von Terminologien es gibt eine ganze Reihe von Terminologien in der objektorientierten Programmierung, in der objektorientierten Programmierung, von denen man so ganz grob zumindest eine Vorstellung haben sollte, von denen man so ganz grob zumindest eine Vorstellung haben sollte, wenn man wirklich objektorientiert programmiert. wenn man wirklich objektorientiert programmiert.

# %% [markdown]
# Initialisierung von Intanzen
# Wenn Sie hier bestimmte Zeilen im Transkript auswählen, wird die entsprechende Zeitmarke im Video angesteuert.
# Angenommen Sie haben irgendeine Klasse in Python, dann ist es relativ einfach möglich, daraus ein Objekt zu erzeugen. Sie schreiben einfach den Konstruktor hin. Beispielweise wenn Sie hier eine Klasse Konto haben, dann machen Sie Konto () und damit wird ein Objekt erzeugt vom Typ Konto. Nun ist es in der Regel nicht sinnvoll, dass Objekte erzeugt werden, ohne dass die Eigenschaften vernünftig initialisiert werden. Das Problem ist jetzt, wenn wir uns diese Klasse Konto betrachten, dass diese Eigenschaften hier Klasseneigenschaften sind, Klassenmember. Klassenmember werden in Python einfach als Variablen direkt in der Klasse deklariert, und damit stehen sie auch allen Instanzen gleich zur Verfügung. Das würde aber auch bedeuten, dass sich der Kontostand in allen Objekten dieses Types ändern würde, wenn es in einem Objekt geändert wird oder in der Klasse. Wenn man jetzt Eigenschaften beim Erzeugen eines Objekts von einem bestimmten Typ direkt initialisieren möchte, dann wird man in einer Methode mit Namen init, eine magische Methode, diese Instanzeigenschaften anlegen. Dabei werden Instanzmethoden in Python immer als ersten Parameter self notieren. Das ist der Verweis auf das anonyme Objekt, ein Objektreferenz, und dann kann man beispielsweise hier kontostand und kontotyp als Parameter übergeben. Im inneren von dieser magischen Methode, die als eine Art Ersatz für einen parametrisierten Konstruktor aus anderen Programmiersprachen zu sehen ist, aus anderen objektorientierten Sprachen. Diese kann man jetzt über das Schlüsselwort self eine Instanzvariable anlegen. Und der weist man dann beispielsweise den Wert, zu der hier über diesen Parameter kontostand übergeben wird. Bitte beachten Sie, es ist kein Zufall, dass der Name der lokalen Variable, also dieses Parameters und der Name der Instanzeigenschaft gleich gewählt wird. Ganz im Gegenteil, es ist sogar gängige Strategie, so etwas zu machen, weil man in diesem Moment immer genau weiß, was welcher Eigenschaft zugewiesen wird. Volkommen Analog würde ich dann hier den Kontotyp auf diese Weise zuweisen. Wenn ich jetzt dieses Mal speichere und ich rufe das Programm auf, dann bekommen Sie einen Fehler. Und das liegt eben daran, dass jetzt diese magische Methode init zwei Parameter zwingend benötigt, nämlich für den Kontostand und den Kontotyp. Und das bedeutet, ich müsste jetzt hier vielleicht für den Kontostand und für den Kontotyp girokonto oder so übergeben. Schaue mir das einmal groß, es spielt keine Rolle. Aber wenn ich das jetzt laufen lasse, dann sehen Sie, dass es jetzt keine Fehlermeldung mehr gibt.
